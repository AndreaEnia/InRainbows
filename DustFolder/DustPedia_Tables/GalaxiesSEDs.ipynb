# %%
import os, sys, subprocess
import numpy as np, pandas as pd
import matplotlib.pyplot as plt

# To import Dustpedia Scripts
sys.path.insert(0, '../')
import DustpediaScripts as DS

# %%
fot_0628 = pd.read_csv('../NGC0628/MyReduction/AUTO_Dustpedia_Photometry.csv', sep = '\t')
wvl_0628, flux_0628 = fot_0628['wvl'].values, fot_0628['flux'].values
fot_3184 = pd.read_csv('../NGC3184/MyReduction/AUTO_Dustpedia_Photometry.csv', sep = '\t')
wvl_3184, flux_3184 = fot_3184['wvl'].values, fot_3184['flux'].values
fot_6946 = pd.read_csv('../NGC6946/MyReduction/AUTO_Dustpedia_Photometry.csv', sep = '\t')
wvl_4254, flux_4254 = fot_4254['wvl'].values, fot_4254['flux'].values
fot_4321 = pd.read_csv('../NGC4321/MyReduction/AUTO_Dustpedia_Photometry.csv', sep = '\t')
wvl_4321, flux_4321 = fot_4321['wvl'].values, fot_4321['flux'].values
fot_4535 = pd.read_csv('../NGC4535/MyReduction/AUTO_Dustpedia_Photometry.csv', sep = '\t')
wvl_4535, flux_4535 = fot_4535['wvl'].values, fot_4535['flux'].values
fot_4736 = pd.read_csv('../NGC4736/MyReduction/AUTO_Dustpedia_Photometry.csv', sep = '\t')
wvl_4736, flux_4736 = fot_4736['wvl'].values, fot_4736['flux'].values
fot_5194 = pd.read_csv('../NGC5194/MyReduction/AUTO_Dustpedia_Photometry.csv', sep = '\t')
wvl_5194, flux_5194 = fot_5194['wvl'].values, fot_5194['flux'].values
fot_5457 = pd.read_csv('../NGC5457/MyReduction/AUTO_Dustpedia_Photometry.csv', sep = '\t')
wvl_5457, flux_5457 = fot_5457['wvl'].values, fot_5457['flux'].values

# %%
SED = plt.figure(figsize=(20,5))
plt.plot(wvl_0628, flux_0628, marker = 'o', linestyle = 'None', label = 'NGC0628')
plt.plot(wvl_3184, flux_3184, marker = '*', linestyle = 'None', label = 'NGC3184')
plt.plot(wvl_4254, flux_4254, marker = 'X', linestyle = 'None', label = 'NGC4254')
plt.plot(wvl_4321, flux_4321, marker = '^', linestyle = 'None', label = 'NGC4321')
plt.plot(wvl_4535, flux_4535, marker = 'P', linestyle = 'None', label = 'NGC4535')
plt.plot(wvl_4736, flux_4736, marker = '3', ms = 15, linestyle = 'None', label = 'NGC4736')
plt.plot(wvl_5194, flux_5194, marker = 'D', linestyle = 'None', label = 'NGC5194')
plt.plot(wvl_5457, flux_5457, marker = 's', linestyle = 'None', label = 'NGC5457')
plt.xscale('log'), plt.yscale('log')
plt.legend(ncol = 2)
plt.show()
